# %%
import pandas as pd
import numpy as np
import datetime as dt
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

# %%
#import CSV from project github

covid19Dataframe = pd.read_csv("covid19Dataframe1.csv")

# %%
covid19Dataframe.to_csv('covid19Dataframe1.csv',index=False)

# %%
#Create a data frame that only has North America data
covid19DataframeNorthAmerica = (covid19Dataframe[covid19Dataframe["continent"]=="North America"]).copy()
covid19DataframeNorthAmerica.head()
# Out:
#      iso_code      continent  location        date  total_cases_per_million  \
# 1786      AIA  North America  Anguilla  2021-02-04                      NaN
# 1787      AIA  North America  Anguilla  2021-02-05                      NaN
# 1788      AIA  North America  Anguilla  2021-02-06                      NaN
# 1789      AIA  North America  Anguilla  2021-02-07                      NaN
# 1790      AIA  North America  Anguilla  2021-02-08                      NaN
#
#       total_deaths_per_million  positive_rate  stringency_index  \
# 1786                       NaN            NaN               NaN
# 1787                       NaN            NaN               NaN
# 1788                       NaN            NaN               NaN
# 1789                       NaN            NaN               NaN
# 1790                       NaN            NaN               NaN
#
#       population_density  median_age  ...  life_expectancy  \
# 1786                 NaN         NaN  ...            81.88
# 1787                 NaN         NaN  ...            81.88
# 1788                 NaN         NaN  ...            81.88
# 1789                 NaN         NaN  ...            81.88
# 1790                 NaN         NaN  ...            81.88
#
#       human_development_index         Day       Month        Year  Year_Month  \
# 1786                      NaN  2021-02-04  2021-02-04  2021-02-04  2021-02-04
# 1787                      NaN  2021-02-05  2021-02-05  2021-02-05  2021-02-05
# 1788                      NaN  2021-02-06  2021-02-06  2021-02-06  2021-02-06
# 1789                      NaN  2021-02-07  2021-02-07  2021-02-07  2021-02-07
# 1790                      NaN  2021-02-08  2021-02-08  2021-02-08  2021-02-08
#
#       Day.1  Month.1  Year.1  Year_Month.1
# 1786      4        2    2021    2021-02-01
# 1787      5        2    2021    2021-02-01
# 1788      6        2    2021    2021-02-01
# 1789      7        2    2021    2021-02-01
# 1790      8        2    2021    2021-02-01
#
# [5 rows x 28 columns]

# %%
sns.heatmap(covid19DataframeNorthAmerica.corr(),cmap='coolwarm')
